# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Carlo-Broschi/statistics-python-for-students/blob/main/01_Python%E5%9F%BA%E7%A4%8E/02_%E5%A4%89%E6%95%B0%E3%83%BB%E6%95%B0%E3%83%BB%E6%96%87%E5%AD%97%E5%88%97.ipynb)
#
# > 🟢 **Colab（ブラウザ）で実行できます。** Privateリポジトリは初回にColabでGitHub連携の許可が必要です。そのまま上から順に実行できます。

# %% [markdown]
# # 02. 変数・数・文字列
#
# **ゴール**
# - 変数に値を入れて使い回せる
# - 整数・小数・文字列・真偽値の違いがわかる
# - 文字列を組み立てて表示できる（f-string）

# %% [markdown]
# ## 1. 変数 = 名前のついた箱
#
# `名前 = 値` で、値に名前をつけて保存できます。

# %%
name = "山田はなこ"   # 文字列を変数 name に入れる
age = 15              # 整数を age に入れる
height = 158.5        # 小数を height に入れる
print(name, age, height)  # 3つの変数の中身をまとめて表示

# %% [markdown]
# 変数はあとから中身を変えたり、計算に使ったりできます。

# %%
age = age + 1   # 今の age に1を足して入れ直す（1歳ふえた）
print(age)      # 更新後の age を表示

# %% [markdown]
# ## 2. データの種類（型）
#
# 値には **型** があります。`type()` で調べられます。
#
# | 型 | 意味 | 例 |
# |---|---|---|
# | `int` | 整数 | `15` |
# | `float` | 小数 | `158.5` |
# | `str` | 文字列 | `"はなこ"` |
# | `bool` | 真偽 | `True` / `False` |

# %%
print(type(15))        # 整数の型を調べる → int
print(type(158.5))     # 小数の型 → float
print(type("はなこ"))   # 文字列の型 → str
print(type(True))      # 真偽値の型 → bool

# %% [markdown]
# ### 型を変える（キャスト）
# `input()` で受け取った値は文字列になります。計算するには数に変換が必要です。

# %%
moji = "100"              # 見た目は数字だが、これは文字列
print(moji + moji)        # 文字列の + は連結 → 100100
print(int(moji) + 50)     # int()で数に変換してから計算 → 150

# %% [markdown]
# ## 3. 文字列を組み立てる（f-string）
#
# `f"...{変数}..."` と書くと、`{}` の中に変数の値が入ります。とても便利！

# %%
name = "はなこ"   # 名前
age = 15          # 年齢
print(f"{name}さんは{age}歳です。来年は{age + 1}歳。")  # f-stringで変数を文に埋め込む

# %% [markdown]
# ### 文字列の便利ワザ

# %%
s = "Python"         # 文字列を変数 s に入れる
print(len(s))        # 文字数 → 6
print(s.upper())     # 大文字に変換 → PYTHON
print(s * 3)         # 文字列をくり返す → PythonPythonPython
print(s[0])          # 先頭の1文字を取り出す → P

# %% [markdown]
# ---
# ## 🏆 練習問題
#
# **問1.** `radius = 5` として、半径5cmの円の面積（`半径 × 半径 × 3.14`）を計算し、
# 「面積は ○○ 平方cmです」と f-string で表示しよう。
#
# **問2.** 自分の名前 `name` と生まれ年 `birth = 2010` を変数にし、
# 「2026年に○○歳になります」と表示しよう。
#
# **問3.** `"あ" * 10` を実行して結果を予想してから確かめよう。

# %%
# 問1

# %%
# 問2

# %%
# 問3

# %% [markdown]
# > 🔑 **解答例は別ページにまとめています**（ネタバレ防止）。
# > 自分で解いてから 👉 **[02_変数・数・文字列 の解答例を開く](https://github.com/Carlo-Broschi/statistics-python-for-students/blob/main/%E8%A7%A3%E7%AD%94%E9%9B%86/01_Python%E5%9F%BA%E7%A4%8E/02_%E5%A4%89%E6%95%B0%E3%83%BB%E6%95%B0%E3%83%BB%E6%96%87%E5%AD%97%E5%88%97.md)**
