# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Carlo-Broschi/statistics-python-for-students/blob/main/01_Python%E5%9F%BA%E7%A4%8E/01_Python%E3%82%92%E3%81%AF%E3%81%98%E3%82%81%E3%82%88%E3%81%86.ipynb)
#
# > Colabで実行可。最初に「① セットアップ」セルを実行（Colabはデータを自動生成、ローカルは何もしない）。

# %% [markdown]
# # 01. Pythonをはじめよう
#
# **このノートのゴール**
# - Jupyter Notebook の使い方がわかる
# - `print()` で文字や数を表示できる
# - 計算の答えをコンピュータに出してもらえる
# - エラーが出ても落ち着いて読めるようになる
#
# > セルを選んで **Shift + Enter** を押すと、そのセルが実行されます。やってみよう！

# %% [markdown]
# ## 1. はじめての `print`
#
# コンピュータに文字を表示してもらうには `print()` を使います。
# 表示したい文字は **ダブルクォート `"`** で囲みます。

# %%
print("こんにちは、Python！")  # 文字を画面に表示する

# %%
# ここに書いて試してみよう

# %%
print("わたしの名前は ○○ です")  # ○○ を自分の名前に変えてみよう

# %%
# ここに書いて試してみよう

# %% [markdown]
# `#` から後ろは **コメント** です。プログラムには影響せず、メモとして使えます。

# %% [markdown]
# ## 2. Pythonは電卓になる
#
# 数の計算もできます。記号の意味はこちら。
#
# | 記号 | 意味 | 例 |
# |---|---|---|
# | `+` | たし算 | `3 + 4` |
# | `-` | ひき算 | `10 - 2` |
# | `*` | かけ算 | `6 * 7` |
# | `/` | わり算 | `10 / 4` |
# | `//` | わり算の商（整数） | `10 // 4` |
# | `%` | わり算のあまり | `10 % 4` |
# | `**` | べき乗 | `2 ** 10` |

# %%
3 + 4  # セルの最後の式の値は自動で表示される（ここでは 7）

# %%
# ここに書いて試してみよう

# %% [markdown]
# > セルの**最後の行**の値は、`print` を書かなくても自動で表示されます。

# %%
print(10 / 4)   # わり算は小数になる
print(10 // 4)  # 商
print(10 % 4)   # あまり
print(2 ** 10)  # 2の10乗

# %%
# ここに書いて試してみよう

# %% [markdown]
# ### 計算の順番
# 算数と同じで、かけ算・わり算が先。順番を変えたいときは `()` を使います。

# %%
print(2 + 3 * 4)     # = 14
print((2 + 3) * 4)   # = 20

# %%
# ここに書いて試してみよう

# %% [markdown]
# ## 3. エラーはこわくない
#
# わざと間違えてみましょう。下のセルを実行するとエラーが出ます。

# %%
print("とじカッコを忘れた"  # わざとエラー：閉じカッコ ) を忘れている

# %%
# ここに書いて試してみよう

# %% [markdown]
# 赤い文字の最後の行に注目！ `SyntaxError`（書き方の間違い）と書いてあります。
# **エラーメッセージの最後の行を読む**のがデバッグの第一歩です。
#
# 上のセルを `print("とじカッコを忘れた")` に直して、もう一度実行してみよう。

# %% [markdown]
# ---
# ## 練習問題
#
# **問1.** あなたの好きな食べ物を `print` で表示しよう。
#
# **問2.** 「1年は何分か」を計算で求めて表示しよう（ヒント：365日 × 24時間 × 60分）。
#
# **問3.** `2026 % 4` を計算しよう。あまりが 0 ならうるう年の候補です。2026年はどうかな？

# %%
# 問1

# %%
# 問2

# %%
# 問3

# %% [markdown]
# > **解答例は別ページにまとめています**（ネタバレ防止）。
# > 自分で解いてから **[01_Pythonをはじめよう の解答例を開く](https://github.com/Carlo-Broschi/statistics-python-for-students/blob/main/%E8%A7%A3%E7%AD%94%E9%9B%86/01_Python%E5%9F%BA%E7%A4%8E/01_Python%E3%82%92%E3%81%AF%E3%81%98%E3%82%81%E3%82%88%E3%81%86.md)**

# %% [markdown]
# ## 完了ログ
#
# このノートを終えたら下のセルを実行すると、学習の完了が記録されます。
# **学習者コードは最初に一度だけ設定**すれば、以降は全ノートで自動送信されます（名前の再入力は不要）。
#
# - Colab：左の鍵アイコン（シークレット）で `STUDENT_CODE` に配布コードを登録（1回だけ）
# - ローカル：環境変数 `STUDENT_CODE` を設定（または初回に画面入力すると保存され、次回から不要）

# %%
# === 完了ログ ===  学習者コードは最初に一度だけ設定すれば、全ノートで自動送信されます。
import os, datetime, pathlib
try:
    import requests
except ImportError:
    requests = None

def _student_code():
    try:                                          # Colab: 鍵アイコンで STUDENT_CODE を登録
        from google.colab import userdata
        c = userdata.get('STUDENT_CODE')
        if c: return c.strip()
    except Exception:
        pass
    c = os.environ.get('STUDENT_CODE')            # ローカル: 環境変数
    if c: return c.strip()
    p = pathlib.Path.home() / '.student_code'      # 保存ファイル
    if p.exists(): return p.read_text().strip()
    try:                                           # 最後の手段: 入力して保存（次回から不要）
        c = input('学習者コードを入力（配布されたもの）: ').strip()
        if c: p.write_text(c); return c
    except Exception:
        pass
    return ''

CODE = _student_code()
LOG_URL = ""      # 配布時に設定
LOG_TOKEN = ""    # 配布時に設定
NOTEBOOK = "01_Python基礎/01_Pythonをはじめよう"

if CODE and LOG_URL and requests:
    try:
        requests.post(LOG_URL, json={"token": LOG_TOKEN, "code": CODE, "notebook": NOTEBOOK,
                      "time": datetime.datetime.now().isoformat(timespec="seconds")}, timeout=10)
        print(f"記録しました: {CODE} / {NOTEBOOK}")
    except Exception as e:
        print("記録に失敗しました（URL/ネットワークを確認）:", e)
elif not CODE:
    print("学習者コード未設定。Colabは鍵アイコンで STUDENT_CODE を登録、ローカルは環境変数 STUDENT_CODE を設定してください。")
else:
    print(f"{NOTEBOOK}: LOG_URL/LOG_TOKEN が未設定です（配布時に設定されます）。")
